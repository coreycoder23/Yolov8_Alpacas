# %% [markdown]
# #IMPORT LIBRARIES

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/ComputerVisionDeveloper/TrainYolov8CustomDataset/data'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.0/715.0 kB 10.3 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml') #build a model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=100) #train the model
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/ComputerVisionDeveloper/TrainYolov8CustomDataset'
